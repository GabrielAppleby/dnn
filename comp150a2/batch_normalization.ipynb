# %% [markdown]
# # Batch Normalization
#
# In this task, we implement batch normalization, which normalizes hidden layers and makes the training procedure more stable.
#
# Reference: [Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing
# Internal Covariate Shift", ICML 2015.](https://arxiv.org/abs/1502.03167)

# %%
# As usual, a bit of setup
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from data_utils import get_CIFAR10_data
from implementations.layers import batchnorm_forward

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def print_mean_std(x,axis=0):
    print('  means: ', x.mean(axis=axis))
    print('  stds:  ', x.std(axis=axis))
    print()

# %%
# Load the (preprocessed) CIFAR10 data.
data = get_CIFAR10_data()
for k, v in data.items():
  print('%s: ' % k, v.shape)
# Out:
# X_train:  (49000, 3, 32, 32)
# y_train:  (49000,)
# X_val:  (1000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# ## Batch normalization: forward
# In the file `implementations/layers.py`, implement the batch normalization forward pass in the function `batchnorm_forward`. Once you have done so, run the following to test your implementation.
#
# Referencing the paper linked to above would be helpful!

# %%
# A very simple example

xtrain = np.array([[10], [20], [30]])

xtest = np.array([[25]])


# initialize parameters for batch normalization
bn_param = {}
bn_param['mode'] = 'train'
bn_param['eps'] = 1e-4
bn_param['momentum'] = 0.95

# initialize the running mean as zero and the running variance as one 
bn_param['running_mean'] = np.zeros([1, xtrain.shape[1]])
bn_param['running_var'] = np.ones([1, xtrain.shape[1]])

# gamma and beta do not make changes to the standardization result from the first step. 
gamma = np.ones([1])
beta = np.zeros([1])

print('Before batch normalization, xtrain has ')
print_mean_std(xtrain,axis=0)

xnorm = batchnorm_forward(xtrain, gamma, beta, bn_param)

print('After batch normalization, xtrain has ')
print_mean_std(xnorm,axis=0) # The mean and std should be 0 and 1 respectively


print('After batch normalization, the running mean and the running variance are updated to')
print(bn_param['running_mean']) # should be 1.0
print(bn_param['running_var']) # should be 4.283


for iter in range(1000):
    xnorm = batchnorm_forward(xtrain, gamma, beta, bn_param)
    
print('After many iterations, the running mean and the running variance are updated to')
print(bn_param['running_mean']) # should be 20, the mean of xtrain
print(bn_param['running_var']) # should be 66.667, the variance of xtrain


# enter test mode, 
bn_param['mode'] = 'test'
xtest_norm = batchnorm_forward(xtest, gamma, beta, bn_param)

print('Before batch normalization, xtest becomes ') # should be [[0.61237198]]
print(xtest_norm)
# Out:
# Before batch normalization, xtrain has
#   means:  [20.]
#   stds:   [8.16496581]
#
# After batch normalization, xtrain has
#   means:  [0.]
#   stds:   [0.99999925]
#
# After batch normalization, the running mean and the running variance are updated to
# [[1.]]
# [[4.28333333]]
# After many iterations, the running mean and the running variance are updated to
# [[20.]]
# [[66.66666667]]
# Before batch normalization, xtest becomes
# [[0.61237198]]

# %%
# Compare with tf.layers.batch_normalization 

# Simulate the forward pass for a two-layer network
np.random.seed(15009)
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)

W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)


# initialize parameters for batch normalization
bn_param = {}
bn_param['mode'] = 'train'
bn_param['eps'] = 1e-4
bn_param['momentum'] = 0.95
bn_param['running_mean'] = np.zeros([1, a.shape[1]])
bn_param['running_var'] = np.ones([1, a.shape[1]])

# random gamma and beta
gamma = np.random.rand(D3) + 1.0
beta = np.random.rand(D3)


# Setting up a tensorflow bn layer using the same set of parameters. 

tf.reset_default_graph()
tfa = tf.placeholder(tf.float32, shape=[None, a.shape[1]])

# used to control the mode
is_training = tf.placeholder_with_default(False, (), 'is_training')

# the axis setting is a little strange to me. But you can understand it as that the axis is along 
# the running mean
tfa_norm = tf.layers.batch_normalization(tfa, axis=1, momentum=0.95, epsilon=bn_param['eps'],
                                         beta_initializer=tf.constant_initializer(beta), 
                                         gamma_initializer=tf.constant_initializer(gamma), 
                                         moving_mean_initializer=tf.zeros_initializer(), 
                                         moving_variance_initializer=tf.ones_initializer(), 
                                         training=is_training)

# this operation is for undating running mean and running variance. 
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

session = tf.Session()

# initialize parameters
session.run(tf.global_variables_initializer())


outputs = []
nbatch = 3
batch_size=10
                     
for ibatch in range(nbatch):
    
    # fetch the batch
    a_batch = a[ibatch * batch_size : (ibatch + 1) * batch_size]
    
    # batch normlaization with your implementation
    a_nprun = batchnorm_forward(a_batch, gamma, beta, bn_param)
    
    # batch normalization with the tensorflow layer. Also update the running mean and variance. 
    a_tfrun, _ = session.run([tfa_norm, update_ops], feed_dict={tfa: a_batch.astype(np.float32), is_training: True})
    
    print("Training batch %d: difference from the two implementations is %f" % (ibatch, rel_error(a_nprun, a_tfrun)))

    
# enterining test mode    
bn_param['mode'] = 'test'
          
for ibatch in range(nbatch):
    a_batch = a[ibatch * batch_size : (ibatch + 1) * batch_size]
    
    a_nprun = batchnorm_forward(a_batch, gamma, beta, bn_param)
    
    # run batch normalization in test mode. No need to update the running mean and variance. 
    a_tfrun = session.run(tfa_norm, feed_dict={tfa: a_batch.astype(np.float32)})

    
    print("Test batch %d: difference from the two implementations is %f" % (ibatch, rel_error(a_nprun, a_tfrun)))
# Out:
# Training batch 0: difference from the two implementations is 0.000001
# Training batch 1: difference from the two implementations is 0.000015
# Training batch 2: difference from the two implementations is 0.000001
# Test batch 0: difference from the two implementations is 0.000000
# Test batch 1: difference from the two implementations is 0.000000
# Test batch 2: difference from the two implementations is 0.000002

# %% [markdown]
# ## Fully Connected Nets with Batch Normalization
# Now that you have a working implementation for batch normalization. Then you need to go back to your `FullyConnectedNet` in the file `implementations/fc_net.py`. Modify the implementation to add batch normalization.
#
# When the `use_bn` flag is set, the network should apply batch normalization before each ReLU nonlinearity. The outputs from the last layer of the network should not be normalized.

# %% [markdown]
# # Batchnorm for deep networks
# Run the following to train a six-layer network on a subset of 1000 training examples both with and without batch normalization.

# %%
from implementations.fc_net import FullyConnectedNet

np.random.seed(15009)
# Try training a very deep net with batchnorm
hidden_dims = [100, 100, 100, 100, 100]

num_train = 1000

X_train = data['X_train'][:num_train]
X_train = np.reshape(X_train, [X_train.shape[0], -1])
y_train = data['y_train'][:num_train]
                               
X_val = data['X_val']
X_val = np.reshape(X_val, [X_val.shape[0], -1])
y_val = data['y_val']


bn_model = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10, 
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=True)

# use an aggresive learning rate
bn_trace = bn_model.train(X_train, y_train, X_val, y_val,
                          learning_rate=5e-4,
                          reg=np.float32(0.01), 
                          keep_prob=0.5,
                          num_iters=800,
                          batch_size=100, 
                          verbose=True) # train the model with batch normalization
# Out:
# iteration 0 / 800: objective 232.335617
# iteration 100 / 800: objective 63.113007
# iteration 200 / 800: objective 6.311312
# iteration 300 / 800: objective 3.959004
# iteration 400 / 800: objective 3.420113
# iteration 500 / 800: objective 3.161806
# iteration 600 / 800: objective 3.008351
# iteration 700 / 800: objective 2.906614

# %% [markdown]
# Train a fully connected network without batch normalization

# %%
model = FullyConnectedNet(input_size=X_train.shape[1], 
                          hidden_size=hidden_dims, 
                          output_size=10, 
                          centering_data=True, 
                          use_dropout=False, 
                          use_bn=False)

# use an aggresive learning rate
baseline_trace = model.train(X_train, y_train, X_val, y_val,
                            learning_rate=5e-4,
                            reg=np.float32(0.01), 
                            num_iters=800,
                            batch_size=100, 
                            verbose=True) # train the model without batch normalization
# Out:
# iteration 0 / 800: objective 232.582138
# iteration 100 / 800: objective 206.285522
# iteration 200 / 800: objective 195.236481
# iteration 300 / 800: objective 140.010254
# iteration 400 / 800: objective 191.665268
# iteration 500 / 800: objective 73.142670
# iteration 600 / 800: objective 114.956703
# iteration 700 / 800: objective 43.332249

# %% [markdown]
# Run the following to visualize the results from two networks trained above. You should find that using batch normalization helps the network to converge much faster.

# %%
def plot_training_history(title, label, bl_plot, bn_plots, bl_marker='.', bn_marker='.', labels=None):
    """utility function for plotting training history"""
    plt.title(title)
    plt.xlabel(label)
    num_bn = len(bn_plots)
    
    for i in range(num_bn):
        label='batch normalization'
        if labels is not None:
            label += str(labels[i])
        plt.plot(bn_plots[i], bn_marker, label=label)
        
    label='baseline'
    if labels is not None:
        label += str(labels[0])
        
    plt.plot(bl_plot, bl_marker, label=label)
    plt.legend(loc='lower center', ncol=num_bn+1) 

    
plt.subplot(3, 1, 1)
plot_training_history('Training loss','Iteration', baseline_trace['objective_history'], \
                      [bn_trace['objective_history']], bl_marker='o', bn_marker='o')
plt.subplot(3, 1, 2)
plot_training_history('Training accuracy','Epoch', baseline_trace['train_acc_history'], \
                      [bn_trace['train_acc_history']], bl_marker='-o', bn_marker='-o')
plt.subplot(3, 1, 3)
plot_training_history('Validation accuracy','Epoch', baseline_trace['val_acc_history'], \
                      [bn_trace['val_acc_history']], bl_marker='-o', bn_marker='-o')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Batch normalization and initialization
# We will now run a small experiment to study the interaction of batch normalization and weight initialization.
#
# The first cell will train 8-layer networks both with and without batch normalization using different scales for weight initialization. The second cell will plot training accuracy, validation set accuracy, and training loss as a function of the weight initialization scale.
#
# LIPING: I tried multiple configurations, but I did not find significant improvement from batch normalization. See if you can get clear improvement with your configurations.

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [50, 50, 50, 50, 50, 50, 50]
num_train = 10000

X_train = data['X_train'][:num_train]
X_train = np.reshape(X_train, [X_train.shape[0], -1])
y_train = data['y_train'][:num_train]
                               
X_val = data['X_val']
X_val = np.reshape(X_val, [X_val.shape[0], -1])
y_val = data['y_val']

bn_net_ws = {}
baseline_ws = {}

# changed from 0 to 4
weight_scales = np.logspace(-8, 8, num=40)
for i, weight_scale in enumerate(weight_scales):
  print('Running weight scale=%f at round %d / %d' % (weight_scale, i + 1, len(weight_scales)))


  bn_model = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10, 
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=True)

  # use an aggresive learning rate
  bn_net_ws[weight_scale] = bn_model.train(X_train, y_train, X_val, y_val,
                          learning_rate=1e-2,
                          reg=np.float32(1e-5), 
                          keep_prob=0.5,
                          num_iters=1000,
                          batch_size=100, 
                          verbose=True) # train the model with batch normalization


  model = FullyConnectedNet(input_size=X_train.shape[1], 
                          hidden_size=hidden_dims, 
                          output_size=10, 
                          centering_data=True, 
                          use_dropout=False, 
                          use_bn=True)

  # use an aggresive learning rate
  baseline_ws[weight_scale] = model.train(X_train, y_train, X_val, y_val,
                            learning_rate=1e-2,
                            reg=np.float32(1e-5), 
                            num_iters=1000,
                            batch_size=100, 
                            verbose=True)
# Out:
# Running weight scale=0.000000 at round 1 / 40
# iteration 0 / 1000: objective 233.189835
# iteration 100 / 1000: objective 209.963455
# iteration 200 / 1000: objective 197.324417
# iteration 300 / 1000: objective 186.545029
# iteration 400 / 1000: objective 175.528427
# iteration 500 / 1000: objective 171.283646
# iteration 600 / 1000: objective 163.023499
# iteration 700 / 1000: objective 157.129608
# iteration 800 / 1000: objective 142.982574
# iteration 900 / 1000: objective 138.170853
# iteration 0 / 1000: objective 230.705185
# iteration 100 / 1000: objective 208.005951
# iteration 200 / 1000: objective 197.166794
# iteration 300 / 1000: objective 194.682663
# iteration 400 / 1000: objective 186.664139
# iteration 500 / 1000: objective 177.741699
# iteration 600 / 1000: objective 167.384048
# iteration 700 / 1000: objective 162.365540
# iteration 800 / 1000: objective 151.862289
# iteration 900 / 1000: objective 151.005508
# Running weight scale=0.000000 at round 2 / 40
# iteration 0 / 1000: objective 231.216507
# iteration 100 / 1000: objective 218.093552
# iteration 200 / 1000: objective 209.616806
# iteration 300 / 1000: objective 189.662094
# iteration 400 / 1000: objective 179.959030
# iteration 500 / 1000: objective 179.999084
# iteration 600 / 1000: objective 165.092560
# iteration 700 / 1000: objective 159.638733
# iteration 800 / 1000: objective 148.669312
# iteration 900 / 1000: objective 144.868851
# iteration 0 / 1000: objective 234.763535
# iteration 100 / 1000: objective 208.233154
# iteration 200 / 1000: objective 194.039169
# iteration 300 / 1000: objective 196.594498
# iteration 400 / 1000: objective 184.685593
# iteration 500 / 1000: objective 179.599075
# iteration 600 / 1000: objective 173.435883
# iteration 700 / 1000: objective 167.847000
# iteration 800 / 1000: objective 163.502106
# iteration 900 / 1000: objective 153.227570
# Running weight scale=0.000000 at round 3 / 40
# iteration 0 / 1000: objective 228.916122
# iteration 100 / 1000: objective 218.485138
# iteration 200 / 1000: objective 199.873306
# iteration 300 / 1000: objective 200.212387
# iteration 400 / 1000: objective 197.254257
# iteration 500 / 1000: objective 182.014740
# iteration 600 / 1000: objective 178.800323
# iteration 700 / 1000: objective 167.581863
# iteration 800 / 1000: objective 157.095688
# iteration 900 / 1000: objective 153.520950
# iteration 0 / 1000: objective 228.990707
# iteration 100 / 1000: objective 204.990997
# iteration 200 / 1000: objective 197.685104
# iteration 300 / 1000: objective 193.829315
# iteration 400 / 1000: objective 186.236694
# iteration 500 / 1000: objective 181.042343
# iteration 600 / 1000: objective 176.432312
# iteration 700 / 1000: objective 166.131638
# iteration 800 / 1000: objective 161.733704
# iteration 900 / 1000: objective 157.078613
# Running weight scale=0.000000 at round 4 / 40
# iteration 0 / 1000: objective 230.535248
# iteration 100 / 1000: objective 217.481857
# iteration 200 / 1000: objective 202.145981
# iteration 300 / 1000: objective 198.122360
# iteration 400 / 1000: objective 183.687531
# iteration 500 / 1000: objective 174.820999
# iteration 600 / 1000: objective 170.923386
# iteration 700 / 1000: objective 163.728470
# iteration 800 / 1000: objective 152.917816
# iteration 900 / 1000: objective 143.272369
# iteration 0 / 1000: objective 230.348511
# iteration 100 / 1000: objective 208.698837
# iteration 200 / 1000: objective 208.577393
# iteration 300 / 1000: objective 206.576523
# iteration 400 / 1000: objective 184.721115
# iteration 500 / 1000: objective 179.348297
# iteration 600 / 1000: objective 174.438904
# iteration 700 / 1000: objective 166.832275
# iteration 800 / 1000: objective 155.070389
# iteration 900 / 1000: objective 152.645920
# Running weight scale=0.000000 at round 5 / 40
# iteration 0 / 1000: objective 231.667969
# iteration 100 / 1000: objective 212.343964
# iteration 200 / 1000: objective 195.642914
# iteration 300 / 1000: objective 188.659149
# iteration 400 / 1000: objective 178.427383
# iteration 500 / 1000: objective 169.166870
# iteration 600 / 1000: objective 171.851578
# iteration 700 / 1000: objective 165.387268
# iteration 800 / 1000: objective 151.496414
# iteration 900 / 1000: objective 155.928726
# iteration 0 / 1000: objective 230.594955
# iteration 100 / 1000: objective 210.607452
# iteration 200 / 1000: objective 196.369247
# iteration 300 / 1000: objective 188.984116
# iteration 400 / 1000: objective 179.632538
# iteration 500 / 1000: objective 168.566620
# iteration 600 / 1000: objective 170.372833
# iteration 700 / 1000: objective 153.547150
# iteration 800 / 1000: objective 147.704163
# iteration 900 / 1000: objective 140.857574
# Running weight scale=0.000001 at round 6 / 40
# iteration 0 / 1000: objective 231.056152
# iteration 100 / 1000: objective 207.278900
# iteration 200 / 1000: objective 201.823441
# iteration 300 / 1000: objective 201.474716
# iteration 400 / 1000: objective 186.114105
# iteration 500 / 1000: objective 175.551208
# iteration 600 / 1000: objective 164.705841
# iteration 700 / 1000: objective 158.105988
# iteration 800 / 1000: objective 154.315445
# iteration 900 / 1000: objective 147.020721
# iteration 0 / 1000: objective 230.562363
# iteration 100 / 1000: objective 202.862167
# iteration 200 / 1000: objective 188.293701
# iteration 300 / 1000: objective 184.042892
# iteration 400 / 1000: objective 173.944290
# iteration 500 / 1000: objective 171.753235
# iteration 600 / 1000: objective 169.372147
# iteration 700 / 1000: objective 156.006531
# iteration 800 / 1000: objective 148.865891
# iteration 900 / 1000: objective 141.612030
# Running weight scale=0.000003 at round 7 / 40
# iteration 0 / 1000: objective 232.726456
# iteration 100 / 1000: objective 216.541046
# iteration 200 / 1000: objective 200.464050
# iteration 300 / 1000: objective 189.857727
# iteration 400 / 1000: objective 180.106049
# iteration 500 / 1000: objective 171.648331
# iteration 600 / 1000: objective 168.966644
# iteration 700 / 1000: objective 159.844833
# iteration 800 / 1000: objective 156.946152
# iteration 900 / 1000: objective 151.094650
# iteration 0 / 1000: objective 230.228195
# iteration 100 / 1000: objective 220.115860
# iteration 200 / 1000: objective 206.531281
# iteration 300 / 1000: objective 201.367706
# iteration 400 / 1000: objective 196.069046
# iteration 500 / 1000: objective 182.790253
# iteration 600 / 1000: objective 173.310638
# iteration 700 / 1000: objective 169.579285
# iteration 800 / 1000: objective 162.425522
# iteration 900 / 1000: objective 159.325195
# Running weight scale=0.000007 at round 8 / 40
# iteration 0 / 1000: objective 231.871536
# iteration 100 / 1000: objective 216.475189
# iteration 200 / 1000: objective 203.525970
# iteration 300 / 1000: objective 200.730530
# iteration 400 / 1000: objective 186.389587
# iteration 500 / 1000: objective 176.666306
# iteration 600 / 1000: objective 170.150986
# iteration 700 / 1000: objective 167.704330
# iteration 800 / 1000: objective 161.188263
# iteration 900 / 1000: objective 150.872391
# iteration 0 / 1000: objective 230.618286
# iteration 100 / 1000: objective 207.678650
# iteration 200 / 1000: objective 201.396973
# iteration 300 / 1000: objective 191.709152
# iteration 400 / 1000: objective 182.506073
# iteration 500 / 1000: objective 160.365585
# iteration 600 / 1000: objective 160.322525
# iteration 700 / 1000: objective 149.259018
# iteration 800 / 1000: objective 148.102554
# iteration 900 / 1000: objective 137.652252
# Running weight scale=0.000019 at round 9 / 40
# iteration 0 / 1000: objective 230.446899
# iteration 100 / 1000: objective 209.954315
# iteration 200 / 1000: objective 195.784470
# iteration 300 / 1000: objective 182.718857
# iteration 400 / 1000: objective 170.397476
# iteration 500 / 1000: objective 162.282623
# iteration 600 / 1000: objective 149.791275
# iteration 700 / 1000: objective 146.769928
# iteration 800 / 1000: objective 141.846375
# iteration 900 / 1000: objective 138.475845
# iteration 0 / 1000: objective 229.329269
# iteration 100 / 1000: objective 205.013992
# iteration 200 / 1000: objective 200.373199
# iteration 300 / 1000: objective 185.760147
# iteration 400 / 1000: objective 181.111099
# iteration 500 / 1000: objective 175.139130
# iteration 600 / 1000: objective 171.679016
# iteration 700 / 1000: objective 161.159195
# iteration 800 / 1000: objective 153.103348
# iteration 900 / 1000: objective 153.342560
# Running weight scale=0.000049 at round 10 / 40
# iteration 0 / 1000: objective 230.764542
# iteration 100 / 1000: objective 212.663589
# iteration 200 / 1000: objective 199.683197
# iteration 300 / 1000: objective 192.393646
# iteration 400 / 1000: objective 178.764786
# iteration 500 / 1000: objective 175.043518
# iteration 600 / 1000: objective 164.460663
# iteration 700 / 1000: objective 161.991791
# iteration 800 / 1000: objective 154.706238
# iteration 900 / 1000: objective 146.056625
# iteration 0 / 1000: objective 232.472290
# iteration 100 / 1000: objective 215.491653
# iteration 200 / 1000: objective 202.462784
# iteration 300 / 1000: objective 194.287643
# iteration 400 / 1000: objective 185.777924
# iteration 500 / 1000: objective 168.952820
# iteration 600 / 1000: objective 166.770844
# iteration 700 / 1000: objective 166.966980
# iteration 800 / 1000: objective 164.944702
# iteration 900 / 1000: objective 148.661087
# Running weight scale=0.000127 at round 11 / 40
# iteration 0 / 1000: objective 232.220703
# iteration 100 / 1000: objective 219.170731
# iteration 200 / 1000: objective 203.143051
# iteration 300 / 1000: objective 195.127914
# iteration 400 / 1000: objective 191.017700
# iteration 500 / 1000: objective 178.074509
# iteration 600 / 1000: objective 175.605469
# iteration 700 / 1000: objective 160.407181
# iteration 800 / 1000: objective 163.543945
# iteration 900 / 1000: objective 152.300537
# iteration 0 / 1000: objective 231.457214
# iteration 100 / 1000: objective 215.116089
# iteration 200 / 1000: objective 203.514633
# iteration 300 / 1000: objective 197.807144
# iteration 400 / 1000: objective 188.513031
# iteration 500 / 1000: objective 179.254486
# iteration 600 / 1000: objective 172.708862
# iteration 700 / 1000: objective 163.077698
# iteration 800 / 1000: objective 151.271088
# iteration 900 / 1000: objective 154.303314
# Running weight scale=0.000326 at round 12 / 40
# iteration 0 / 1000: objective 231.206009
# iteration 100 / 1000: objective 219.461105
# iteration 200 / 1000: objective 202.255798
# iteration 300 / 1000: objective 191.462143
# iteration 400 / 1000: objective 183.930573
# iteration 500 / 1000: objective 169.909393
# iteration 600 / 1000: objective 167.176895
# iteration 700 / 1000: objective 159.896912
# iteration 800 / 1000: objective 155.594574
# iteration 900 / 1000: objective 147.865906
# iteration 0 / 1000: objective 230.952698
# iteration 100 / 1000: objective 210.031006
# iteration 200 / 1000: objective 195.590164
# iteration 300 / 1000: objective 186.304733
# iteration 400 / 1000: objective 184.902802
# iteration 500 / 1000: objective 174.996353
# iteration 600 / 1000: objective 169.853424
# iteration 700 / 1000: objective 161.881836
# iteration 800 / 1000: objective 155.780701
# iteration 900 / 1000: objective 148.561127
# Running weight scale=0.000838 at round 13 / 40
# iteration 0 / 1000: objective 230.868286
# iteration 100 / 1000: objective 206.593414
# iteration 200 / 1000: objective 204.348251
# iteration 300 / 1000: objective 194.009583
# iteration 400 / 1000: objective 185.413940
# iteration 500 / 1000: objective 182.425308
# iteration 600 / 1000: objective 172.558594
# iteration 700 / 1000: objective 169.131744
# iteration 800 / 1000: objective 165.506744
# iteration 900 / 1000: objective 159.161865
# iteration 0 / 1000: objective 229.857712
# iteration 100 / 1000: objective 207.738464
# iteration 200 / 1000: objective 203.465317
# iteration 300 / 1000: objective 190.376053
# iteration 400 / 1000: objective 186.191940
# iteration 500 / 1000: objective 180.765823
# iteration 600 / 1000: objective 169.518341
# iteration 700 / 1000: objective 161.440247
# iteration 800 / 1000: objective 155.249283
# iteration 900 / 1000: objective 159.191208
# Running weight scale=0.002154 at round 14 / 40
# iteration 0 / 1000: objective 230.686111
# iteration 100 / 1000: objective 215.547409
# iteration 200 / 1000: objective 203.234467
# iteration 300 / 1000: objective 194.418457
# iteration 400 / 1000: objective 183.464920
# iteration 500 / 1000: objective 186.969208
# iteration 600 / 1000: objective 171.135361
# iteration 700 / 1000: objective 161.316940
# iteration 800 / 1000: objective 153.187042
# iteration 900 / 1000: objective 150.583511
# iteration 0 / 1000: objective 231.731705
# iteration 100 / 1000: objective 214.003754
# iteration 200 / 1000: objective 208.749832
# iteration 300 / 1000: objective 198.707016
# iteration 400 / 1000: objective 184.079147
# iteration 500 / 1000: objective 178.787292
# iteration 600 / 1000: objective 167.045395
# iteration 700 / 1000: objective 159.623428
# iteration 800 / 1000: objective 157.201553
# iteration 900 / 1000: objective 157.953979
# Running weight scale=0.005541 at round 15 / 40
# iteration 0 / 1000: objective 229.332108
# iteration 100 / 1000: objective 221.807297
# iteration 200 / 1000: objective 196.926163
# iteration 300 / 1000: objective 191.800507
# iteration 400 / 1000: objective 181.211319
# iteration 500 / 1000: objective 174.669388
# iteration 600 / 1000: objective 161.212967
# iteration 700 / 1000: objective 161.829285
# iteration 800 / 1000: objective 152.611282
# iteration 900 / 1000: objective 145.062668
# iteration 0 / 1000: objective 230.080002
# iteration 100 / 1000: objective 204.181442
# iteration 200 / 1000: objective 197.463409
# iteration 300 / 1000: objective 194.964142
# iteration 400 / 1000: objective 185.408600
# iteration 500 / 1000: objective 177.508362
# iteration 600 / 1000: objective 168.276321
# iteration 700 / 1000: objective 164.333664
# iteration 800 / 1000: objective 161.155273
# iteration 900 / 1000: objective 154.510452
# Running weight scale=0.014251 at round 16 / 40
# iteration 0 / 1000: objective 230.316788
# iteration 100 / 1000: objective 208.651413
# iteration 200 / 1000: objective 207.796265
# iteration 300 / 1000: objective 192.991699
# iteration 400 / 1000: objective 184.099884
# iteration 500 / 1000: objective 172.146820
# iteration 600 / 1000: objective 155.657883
# iteration 700 / 1000: objective 149.995010
# iteration 800 / 1000: objective 147.744186
# iteration 900 / 1000: objective 141.649612
# iteration 0 / 1000: objective 229.165115
# iteration 100 / 1000: objective 217.497437
# iteration 200 / 1000: objective 202.089157
# iteration 300 / 1000: objective 192.722290
# iteration 400 / 1000: objective 188.200943
# iteration 500 / 1000: objective 179.039169
# iteration 600 / 1000: objective 172.072525
# iteration 700 / 1000: objective 168.898804
# iteration 800 / 1000: objective 162.622543
# iteration 900 / 1000: objective 157.532806
# Running weight scale=0.036652 at round 17 / 40
# iteration 0 / 1000: objective 232.182281
# iteration 100 / 1000: objective 209.255920
# iteration 200 / 1000: objective 206.621094
# iteration 300 / 1000: objective 194.579102
# iteration 400 / 1000: objective 182.238678
# iteration 500 / 1000: objective 175.369873
# iteration 600 / 1000: objective 172.713257
# iteration 700 / 1000: objective 169.350830
# iteration 800 / 1000: objective 158.632263
# iteration 900 / 1000: objective 162.868454
# iteration 0 / 1000: objective 230.069305
# iteration 100 / 1000: objective 209.132339
# iteration 200 / 1000: objective 199.405899
# iteration 300 / 1000: objective 188.196472
# iteration 400 / 1000: objective 192.098511
# iteration 500 / 1000: objective 180.769394
# iteration 600 / 1000: objective 178.960083
# iteration 700 / 1000: objective 164.809418
# iteration 800 / 1000: objective 162.438629
# iteration 900 / 1000: objective 158.741806
# Running weight scale=0.094267 at round 18 / 40
# iteration 0 / 1000: objective 231.338120
# iteration 100 / 1000: objective 211.250275
# iteration 200 / 1000: objective 206.118591
# iteration 300 / 1000: objective 196.046738
# iteration 400 / 1000: objective 183.915283
# iteration 500 / 1000: objective 175.531982
# iteration 600 / 1000: objective 170.757797
# iteration 700 / 1000: objective 168.390915
# iteration 800 / 1000: objective 160.855652
# iteration 900 / 1000: objective 158.145340
# iteration 0 / 1000: objective 229.827744
# iteration 100 / 1000: objective 218.392563
# iteration 200 / 1000: objective 200.751541
# iteration 300 / 1000: objective 196.580002
# iteration 400 / 1000: objective 189.044403
# iteration 500 / 1000: objective 176.317276
# iteration 600 / 1000: objective 164.564835
# iteration 700 / 1000: objective 160.009323
# iteration 800 / 1000: objective 149.721619
# iteration 900 / 1000: objective 145.079117
# Running weight scale=0.242446 at round 19 / 40
# iteration 0 / 1000: objective 230.015915
# iteration 100 / 1000: objective 213.357468
# iteration 200 / 1000: objective 200.509079
# iteration 300 / 1000: objective 188.931198
# iteration 400 / 1000: objective 182.849243
# iteration 500 / 1000: objective 170.246063
# iteration 600 / 1000: objective 168.330368
# iteration 700 / 1000: objective 159.664017
# iteration 800 / 1000: objective 153.405716
# iteration 900 / 1000: objective 148.734146
# iteration 0 / 1000: objective 229.280273
# iteration 100 / 1000: objective 214.139389
# iteration 200 / 1000: objective 196.589188
# iteration 300 / 1000: objective 190.117691
# iteration 400 / 1000: objective 186.286362
# iteration 500 / 1000: objective 178.931335
# iteration 600 / 1000: objective 172.872208
# iteration 700 / 1000: objective 174.038589
# iteration 800 / 1000: objective 163.863327
# iteration 900 / 1000: objective 155.265930
# Running weight scale=0.623551 at round 20 / 40
# iteration 0 / 1000: objective 229.734772
# iteration 100 / 1000: objective 206.736298
# iteration 200 / 1000: objective 195.839371
# iteration 300 / 1000: objective 190.968018
# iteration 400 / 1000: objective 181.853134
# iteration 500 / 1000: objective 179.584198
# iteration 600 / 1000: objective 171.610184
# iteration 700 / 1000: objective 164.909317
# iteration 800 / 1000: objective 156.089325
# iteration 900 / 1000: objective 147.324722
# iteration 0 / 1000: objective 230.125626
# iteration 100 / 1000: objective 212.467468
# iteration 200 / 1000: objective 207.077393
# iteration 300 / 1000: objective 197.016541
# iteration 400 / 1000: objective 185.833527
# iteration 500 / 1000: objective 181.309479
# iteration 600 / 1000: objective 174.862305
# iteration 700 / 1000: objective 160.007294
# iteration 800 / 1000: objective 150.773743
# iteration 900 / 1000: objective 156.239120
# Running weight scale=1.603719 at round 21 / 40
# iteration 0 / 1000: objective 230.573273
# iteration 100 / 1000: objective 209.825027
# iteration 200 / 1000: objective 205.834061
# iteration 300 / 1000: objective 184.235962
# iteration 400 / 1000: objective 176.196381
# iteration 500 / 1000: objective 164.918076
# iteration 600 / 1000: objective 163.268814
# iteration 700 / 1000: objective 155.639938
# iteration 800 / 1000: objective 144.653107
# iteration 900 / 1000: objective 144.300980
# iteration 0 / 1000: objective 231.645584
# iteration 100 / 1000: objective 217.518295
# iteration 200 / 1000: objective 210.502808
# iteration 300 / 1000: objective 197.425659
# iteration 400 / 1000: objective 185.971893
# iteration 500 / 1000: objective 176.537704
# iteration 600 / 1000: objective 171.881973
# iteration 700 / 1000: objective 164.740631
# iteration 800 / 1000: objective 156.203918
# iteration 900 / 1000: objective 147.063110
# Running weight scale=4.124626 at round 22 / 40
# iteration 0 / 1000: objective 228.895386
# iteration 100 / 1000: objective 214.873474
# iteration 200 / 1000: objective 203.092224
# iteration 300 / 1000: objective 194.009094
# iteration 400 / 1000: objective 183.280777
# iteration 500 / 1000: objective 172.791885
# iteration 600 / 1000: objective 166.485062
# iteration 700 / 1000: objective 156.402908
# iteration 800 / 1000: objective 163.748322
# iteration 900 / 1000: objective 149.113556
# iteration 0 / 1000: objective 231.371704
# iteration 100 / 1000: objective 214.899689
# iteration 200 / 1000: objective 198.600037
# iteration 300 / 1000: objective 190.049500
# iteration 400 / 1000: objective 187.889282
# iteration 500 / 1000: objective 178.067078
# iteration 600 / 1000: objective 173.752869
# iteration 700 / 1000: objective 164.320328
# iteration 800 / 1000: objective 169.263840
# iteration 900 / 1000: objective 163.525757
# Running weight scale=10.608184 at round 23 / 40
# iteration 0 / 1000: objective 234.258377
# iteration 100 / 1000: objective 212.160828
# iteration 200 / 1000: objective 201.443207
# iteration 300 / 1000: objective 190.878296
# iteration 400 / 1000: objective 186.612152
# iteration 500 / 1000: objective 179.925812
# iteration 600 / 1000: objective 165.159119
# iteration 700 / 1000: objective 151.275757
# iteration 800 / 1000: objective 148.672516
# iteration 900 / 1000: objective 150.767502
# iteration 0 / 1000: objective 229.055832
# iteration 100 / 1000: objective 216.329315
# iteration 200 / 1000: objective 203.977493
# iteration 300 / 1000: objective 202.219193
# iteration 400 / 1000: objective 189.499374
# iteration 500 / 1000: objective 179.789001
# iteration 600 / 1000: objective 175.393448
# iteration 700 / 1000: objective 166.279755
# iteration 800 / 1000: objective 158.605560
# iteration 900 / 1000: objective 160.730637
# Running weight scale=27.283334 at round 24 / 40
# iteration 0 / 1000: objective 231.270996
# iteration 100 / 1000: objective 208.130859
# iteration 200 / 1000: objective 192.841919
# iteration 300 / 1000: objective 189.415573
# iteration 400 / 1000: objective 179.392776
# iteration 500 / 1000: objective 170.254486
# iteration 600 / 1000: objective 168.467896
# iteration 700 / 1000: objective 158.775543
# iteration 800 / 1000: objective 147.620193
# iteration 900 / 1000: objective 138.434906
# iteration 0 / 1000: objective 229.972916
# iteration 100 / 1000: objective 214.513519
# iteration 200 / 1000: objective 200.779221
# iteration 300 / 1000: objective 191.201630
# iteration 400 / 1000: objective 188.597427
# iteration 500 / 1000: objective 177.896072
# iteration 600 / 1000: objective 173.159851
# iteration 700 / 1000: objective 167.499222
# iteration 800 / 1000: objective 161.085831
# iteration 900 / 1000: objective 151.859711
# Running weight scale=70.170383 at round 25 / 40
# iteration 0 / 1000: objective 230.458084
# iteration 100 / 1000: objective 207.968063
# iteration 200 / 1000: objective 204.579559
# iteration 300 / 1000: objective 189.994019
# iteration 400 / 1000: objective 177.632217
# iteration 500 / 1000: objective 172.519440
# iteration 600 / 1000: objective 166.858200
# iteration 700 / 1000: objective 155.763702
# iteration 800 / 1000: objective 155.366638
# iteration 900 / 1000: objective 150.792618
# iteration 0 / 1000: objective 229.702698
# iteration 100 / 1000: objective 211.462967
# iteration 200 / 1000: objective 198.250992
# iteration 300 / 1000: objective 187.274704
# iteration 400 / 1000: objective 185.430649
# iteration 500 / 1000: objective 176.381470
# iteration 600 / 1000: objective 169.248611
# iteration 700 / 1000: objective 167.053802
# iteration 800 / 1000: objective 150.040482
# iteration 900 / 1000: objective 149.633926
# Running weight scale=180.472177 at round 26 / 40
# iteration 0 / 1000: objective 229.809296
# iteration 100 / 1000: objective 219.946686
# iteration 200 / 1000: objective 199.305161
# iteration 300 / 1000: objective 186.732605
# iteration 400 / 1000: objective 179.022919
# iteration 500 / 1000: objective 174.138977
# iteration 600 / 1000: objective 167.588547
# iteration 700 / 1000: objective 164.035629
# iteration 800 / 1000: objective 156.052994
# iteration 900 / 1000: objective 156.333176
# iteration 0 / 1000: objective 232.574524
# iteration 100 / 1000: objective 210.439667
# iteration 200 / 1000: objective 197.082230
# iteration 300 / 1000: objective 195.036575
# iteration 400 / 1000: objective 181.931808
# iteration 500 / 1000: objective 179.879333
# iteration 600 / 1000: objective 162.636108
# iteration 700 / 1000: objective 167.182907
# iteration 800 / 1000: objective 153.032257
# iteration 900 / 1000: objective 150.634079
# Running weight scale=464.158883 at round 27 / 40
# iteration 0 / 1000: objective 230.016724
# iteration 100 / 1000: objective 210.637161
# iteration 200 / 1000: objective 196.384155
# iteration 300 / 1000: objective 191.207993
# iteration 400 / 1000: objective 180.022949
# iteration 500 / 1000: objective 171.343781
# iteration 600 / 1000: objective 164.469894
# iteration 700 / 1000: objective 160.017654
# iteration 800 / 1000: objective 162.889359
# iteration 900 / 1000: objective 139.616028
# iteration 0 / 1000: objective 229.505005
# iteration 100 / 1000: objective 211.741714
# iteration 200 / 1000: objective 198.862167
# iteration 300 / 1000: objective 192.162903
# iteration 400 / 1000: objective 197.200455
# iteration 500 / 1000: objective 177.175385
# iteration 600 / 1000: objective 175.399353
# iteration 700 / 1000: objective 166.447769
# iteration 800 / 1000: objective 163.953705
# iteration 900 / 1000: objective 152.314499
# Running weight scale=1193.776642 at round 28 / 40
# iteration 0 / 1000: objective 229.545059
# iteration 100 / 1000: objective 210.389893
# iteration 200 / 1000: objective 200.564865
# iteration 300 / 1000: objective 196.496353
# iteration 400 / 1000: objective 182.880753
# iteration 500 / 1000: objective 182.377472
# iteration 600 / 1000: objective 173.602524
# iteration 700 / 1000: objective 165.977859
# iteration 800 / 1000: objective 161.079285
# iteration 900 / 1000: objective 149.448135
# iteration 0 / 1000: objective 232.723953
# iteration 100 / 1000: objective 211.223953
# iteration 200 / 1000: objective 198.922302
# iteration 300 / 1000: objective 193.327103
# iteration 400 / 1000: objective 183.129898
# iteration 500 / 1000: objective 173.624146
# iteration 600 / 1000: objective 160.821121
# iteration 700 / 1000: objective 159.753967
# iteration 800 / 1000: objective 156.826981
# iteration 900 / 1000: objective 148.401215
# Running weight scale=3070.290630 at round 29 / 40
# iteration 0 / 1000: objective 230.778580
# iteration 100 / 1000: objective 215.767715
# iteration 200 / 1000: objective 202.058701
# iteration 300 / 1000: objective 187.825378
# iteration 400 / 1000: objective 185.180130
# iteration 500 / 1000: objective 179.302109
# iteration 600 / 1000: objective 166.132736
# iteration 700 / 1000: objective 164.137787
# iteration 800 / 1000: objective 157.087067
# iteration 900 / 1000: objective 149.636597
# iteration 0 / 1000: objective 232.493240
# iteration 100 / 1000: objective 217.138824
# iteration 200 / 1000: objective 202.316742
# iteration 300 / 1000: objective 196.897873
# iteration 400 / 1000: objective 185.977844
# iteration 500 / 1000: objective 181.982468
# iteration 600 / 1000: objective 174.695328
# iteration 700 / 1000: objective 162.552826
# iteration 800 / 1000: objective 148.961243
# iteration 900 / 1000: objective 151.597885
# Running weight scale=7896.522868 at round 30 / 40
# iteration 0 / 1000: objective 231.379120
# iteration 100 / 1000: objective 208.946365
# iteration 200 / 1000: objective 196.265167
# iteration 300 / 1000: objective 191.420242
# iteration 400 / 1000: objective 187.137207
# iteration 500 / 1000: objective 172.069778
# iteration 600 / 1000: objective 165.585739
# iteration 700 / 1000: objective 160.745956
# iteration 800 / 1000: objective 156.961487
# iteration 900 / 1000: objective 153.587738
# iteration 0 / 1000: objective 230.467438
# iteration 100 / 1000: objective 212.978043
# iteration 200 / 1000: objective 201.490952
# iteration 300 / 1000: objective 195.837784
# iteration 400 / 1000: objective 192.558426
# iteration 500 / 1000: objective 188.305771
# iteration 600 / 1000: objective 178.114243
# iteration 700 / 1000: objective 170.938492
# iteration 800 / 1000: objective 160.896454
# iteration 900 / 1000: objective 163.427582
# Running weight scale=20309.176209 at round 31 / 40
# iteration 0 / 1000: objective 234.037918
# iteration 100 / 1000: objective 211.046066
# iteration 200 / 1000: objective 197.134277
# iteration 300 / 1000: objective 192.331985
# iteration 400 / 1000: objective 176.469330
# iteration 500 / 1000: objective 169.287140
# iteration 600 / 1000: objective 169.058716
# iteration 700 / 1000: objective 148.168381
# iteration 800 / 1000: objective 145.477661
# iteration 900 / 1000: objective 146.678619
# iteration 0 / 1000: objective 232.746368
# iteration 100 / 1000: objective 208.727982
# iteration 200 / 1000: objective 194.040207
# iteration 300 / 1000: objective 178.624420
# iteration 400 / 1000: objective 175.920853
# iteration 500 / 1000: objective 171.696320
# iteration 600 / 1000: objective 161.828171
# iteration 700 / 1000: objective 157.757019
# iteration 800 / 1000: objective 149.535751
# iteration 900 / 1000: objective 141.206375
# Running weight scale=52233.450743 at round 32 / 40
# iteration 0 / 1000: objective 231.839554
# iteration 100 / 1000: objective 209.918137
# iteration 200 / 1000: objective 199.048676
# iteration 300 / 1000: objective 195.100586
# iteration 400 / 1000: objective 184.703857
# iteration 500 / 1000: objective 175.406357
# iteration 600 / 1000: objective 165.513077
# iteration 700 / 1000: objective 173.215515
# iteration 800 / 1000: objective 160.213394
# iteration 900 / 1000: objective 166.321930
# iteration 0 / 1000: objective 228.479065
# iteration 100 / 1000: objective 218.360031
# iteration 200 / 1000: objective 201.311661
# iteration 300 / 1000: objective 194.446426
# iteration 400 / 1000: objective 173.696182
# iteration 500 / 1000: objective 168.952591
# iteration 600 / 1000: objective 166.958176
# iteration 700 / 1000: objective 159.138245
# iteration 800 / 1000: objective 150.684265
# iteration 900 / 1000: objective 143.064331
# Running weight scale=134339.933260 at round 33 / 40
# iteration 0 / 1000: objective 229.614899
# iteration 100 / 1000: objective 213.602020
# iteration 200 / 1000: objective 204.349197
# iteration 300 / 1000: objective 190.207565
# iteration 400 / 1000: objective 188.424652
# iteration 500 / 1000: objective 172.878479
# iteration 600 / 1000: objective 166.156906
# iteration 700 / 1000: objective 164.214920
# iteration 800 / 1000: objective 152.334747
# iteration 900 / 1000: objective 149.658478
# iteration 0 / 1000: objective 229.726868
# iteration 100 / 1000: objective 205.809677
# iteration 200 / 1000: objective 195.470642
# iteration 300 / 1000: objective 184.488159
# iteration 400 / 1000: objective 177.277084
# iteration 500 / 1000: objective 169.668640
# iteration 600 / 1000: objective 168.443253
# iteration 700 / 1000: objective 159.814743
# iteration 800 / 1000: objective 153.075851
# iteration 900 / 1000: objective 145.415039
# Running weight scale=345510.729459 at round 34 / 40
# iteration 0 / 1000: objective 230.401627
# iteration 100 / 1000: objective 204.186829
# iteration 200 / 1000: objective 209.624695
# iteration 300 / 1000: objective 195.749054
# iteration 400 / 1000: objective 185.408524
# iteration 500 / 1000: objective 183.849716
# iteration 600 / 1000: objective 169.498184
# iteration 700 / 1000: objective 155.032227
# iteration 800 / 1000: objective 150.872513
# iteration 900 / 1000: objective 153.732971
# iteration 0 / 1000: objective 231.083405
# iteration 100 / 1000: objective 205.564087
# iteration 200 / 1000: objective 196.411957
# iteration 300 / 1000: objective 184.899994
# iteration 400 / 1000: objective 175.271683
# iteration 500 / 1000: objective 163.919693
# iteration 600 / 1000: objective 156.608322
# iteration 700 / 1000: objective 152.929169
# iteration 800 / 1000: objective 143.478180
# iteration 900 / 1000: objective 132.055389
# Running weight scale=888623.816274 at round 35 / 40
# iteration 0 / 1000: objective 231.498459
# iteration 100 / 1000: objective 207.980270
# iteration 200 / 1000: objective 196.349487
# iteration 300 / 1000: objective 187.160538
# iteration 400 / 1000: objective 173.809509
# iteration 500 / 1000: objective 170.205185
# iteration 600 / 1000: objective 161.011292
# iteration 700 / 1000: objective 155.864563
# iteration 800 / 1000: objective 150.255768
# iteration 900 / 1000: objective 155.630020
# iteration 0 / 1000: objective 232.050308
# iteration 100 / 1000: objective 217.683716
# iteration 200 / 1000: objective 205.660995
# iteration 300 / 1000: objective 194.979950
# iteration 400 / 1000: objective 193.326950
# iteration 500 / 1000: objective 184.027679
# iteration 600 / 1000: objective 178.762726
# iteration 700 / 1000: objective 164.348083
# iteration 800 / 1000: objective 161.279541
# iteration 900 / 1000: objective 157.699722
# Running weight scale=2285463.864135 at round 36 / 40
# iteration 0 / 1000: objective 228.386703
# iteration 100 / 1000: objective 209.658249
# iteration 200 / 1000: objective 197.471756
# iteration 300 / 1000: objective 189.593582
# iteration 400 / 1000: objective 188.924942
# iteration 500 / 1000: objective 167.060989
# iteration 600 / 1000: objective 157.666809
# iteration 700 / 1000: objective 155.598999
# iteration 800 / 1000: objective 144.584518
# iteration 900 / 1000: objective 144.630524
# iteration 0 / 1000: objective 232.652924
# iteration 100 / 1000: objective 210.831512
# iteration 200 / 1000: objective 201.527069
# iteration 300 / 1000: objective 194.269531
# iteration 400 / 1000: objective 184.141388
# iteration 500 / 1000: objective 172.165970
# iteration 600 / 1000: objective 154.380463
# iteration 700 / 1000: objective 149.601212
# iteration 800 / 1000: objective 147.482819
# iteration 900 / 1000: objective 141.233353
# Running weight scale=5878016.072275 at round 37 / 40
# iteration 0 / 1000: objective 231.261002
# iteration 100 / 1000: objective 209.463806
# iteration 200 / 1000: objective 193.766724
# iteration 300 / 1000: objective 190.710968
# iteration 400 / 1000: objective 179.667084
# iteration 500 / 1000: objective 167.132172
# iteration 600 / 1000: objective 161.790192
# iteration 700 / 1000: objective 163.532379
# iteration 800 / 1000: objective 158.011429
# iteration 900 / 1000: objective 157.099503
# iteration 0 / 1000: objective 230.639832
# iteration 100 / 1000: objective 214.939529
# iteration 200 / 1000: objective 204.105911
# iteration 300 / 1000: objective 190.404037
# iteration 400 / 1000: objective 189.679764
# iteration 500 / 1000: objective 178.223541
# iteration 600 / 1000: objective 169.544968
# iteration 700 / 1000: objective 156.626907
# iteration 800 / 1000: objective 157.033920
# iteration 900 / 1000: objective 152.060211
# Running weight scale=15117750.706157 at round 38 / 40
# iteration 0 / 1000: objective 232.581924
# iteration 100 / 1000: objective 207.034332
# iteration 200 / 1000: objective 205.232437
# iteration 300 / 1000: objective 196.981049
# iteration 400 / 1000: objective 183.006638
# iteration 500 / 1000: objective 174.103241
# iteration 600 / 1000: objective 166.038193
# iteration 700 / 1000: objective 159.790649
# iteration 800 / 1000: objective 157.514893
# iteration 900 / 1000: objective 151.452301
# iteration 0 / 1000: objective 230.290634
# iteration 100 / 1000: objective 216.779510
# iteration 200 / 1000: objective 204.437042
# iteration 300 / 1000: objective 190.169235
# iteration 400 / 1000: objective 184.109039
# iteration 500 / 1000: objective 179.006088
# iteration 600 / 1000: objective 169.329315
# iteration 700 / 1000: objective 167.123413
# iteration 800 / 1000: objective 158.843353
# iteration 900 / 1000: objective 156.645096
# Running weight scale=38881551.803081 at round 39 / 40
# iteration 0 / 1000: objective 231.483612
# iteration 100 / 1000: objective 206.356705
# iteration 200 / 1000: objective 200.297409
# iteration 300 / 1000: objective 192.834595
# iteration 400 / 1000: objective 176.627670
# iteration 500 / 1000: objective 173.924301
# iteration 600 / 1000: objective 168.898102
# iteration 700 / 1000: objective 161.382004
# iteration 800 / 1000: objective 150.985107
# iteration 900 / 1000: objective 147.729141
# iteration 0 / 1000: objective 231.406403
# iteration 100 / 1000: objective 208.871704
# iteration 200 / 1000: objective 200.267792
# iteration 300 / 1000: objective 191.640244
# iteration 400 / 1000: objective 184.179214
# iteration 500 / 1000: objective 176.371216
# iteration 600 / 1000: objective 175.824234
# iteration 700 / 1000: objective 160.184402
# iteration 800 / 1000: objective 159.258621
# iteration 900 / 1000: objective 154.883820
# Running weight scale=100000000.000000 at round 40 / 40
# iteration 0 / 1000: objective 229.852066
# iteration 100 / 1000: objective 211.336243
# iteration 200 / 1000: objective 198.140747
# iteration 300 / 1000: objective 182.927505
# iteration 400 / 1000: objective 176.790329
# iteration 500 / 1000: objective 179.640594
# iteration 600 / 1000: objective 166.187500
# iteration 700 / 1000: objective 157.019730
# iteration 800 / 1000: objective 147.956009
# iteration 900 / 1000: objective 146.889069
# iteration 0 / 1000: objective 231.806915
# iteration 100 / 1000: objective 215.001007
# iteration 200 / 1000: objective 202.565491
# iteration 300 / 1000: objective 188.737961
# iteration 400 / 1000: objective 184.213577
# iteration 500 / 1000: objective 177.138428
# iteration 600 / 1000: objective 170.326416
# iteration 700 / 1000: objective 155.992722
# iteration 800 / 1000: objective 164.326614
# iteration 900 / 1000: objective 158.143021

# %%
# Plot results of weight scale experiment
best_train_accs, bn_best_train_accs = [], []
best_val_accs, bn_best_val_accs = [], []
final_train_loss, bn_final_train_loss = [], []

for ws in weight_scales:
  best_train_accs.append(max(baseline_ws[ws]['train_acc_history']))
  bn_best_train_accs.append(max(bn_net_ws[ws]['train_acc_history']))
  
  best_val_accs.append(max(baseline_ws[ws]['val_acc_history']))
  bn_best_val_accs.append(max(bn_net_ws[ws]['val_acc_history']))
  
  final_train_loss.append(np.mean(baseline_ws[ws]['objective_history'][-100:]))
  bn_final_train_loss.append(np.mean(bn_net_ws[ws]['objective_history'][-100:]))
  
plt.subplot(3, 1, 1)
plt.title('Best val accuracy vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Best val accuracy')
plt.semilogx(weight_scales, best_val_accs, '-o', label='baseline')
plt.semilogx(weight_scales, bn_best_val_accs, '-o', label='batchnorm')
plt.legend(ncol=2, loc='lower right')

plt.subplot(3, 1, 2)
plt.title('Best train accuracy vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Best training accuracy')
plt.semilogx(weight_scales, best_train_accs, '-o', label='baseline')
plt.semilogx(weight_scales, bn_best_train_accs, '-o', label='batchnorm')
plt.legend()

plt.subplot(3, 1, 3)
plt.title('Final training loss vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Final training loss')
plt.semilogx(weight_scales, final_train_loss, '-o', label='baseline')
plt.semilogx(weight_scales, bn_final_train_loss, '-o', label='batchnorm')
plt.legend()
plt.gca().set_ylim(120, 160)

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ## Inline Question 1:
# Describe the results of this experiment. How does the scale of weight initialization affect models with/without batch normalization differently, and why?

# %% [markdown]
# ## Answer:
# It does not seem to make much of a difference for even somewhat reasonable weight initializations, based on the graphics we are presented. As long as the net is pretty shallow and the baseline approach has had enough iterations I don't think batch normalization should have any real effect on final accuracies unless one gets lucky. Batch normalization should just help create a better optimization landscape, allowing one to converge faster and in the case of some deeper nets allowing a convergence at all.

# %% [markdown]
# # Batch normalization and batch size
# We will now run a small experiment to study the interaction of batch normalization and batch size.
#
# The first cell will train 6-layer networks both with and without batch normalization using different batch sizes. The second cell will plot training accuracy and validation set accuracy over time.
#
# Here is a link about batch sizes in batch normalization:
# https://www.graphcore.ai/posts/revisiting-small-batch-training-for-deep-neural-networks

# %%
def run_batchsize_experiments():
    np.random.seed(15009)
    # Try training a very deep net with batchnorm
    hidden_dims = [50, 50, 50, 50, 50]
    
    num_train = 1000

    X_train = data['X_train'][:num_train]
    X_train = np.reshape(X_train, [X_train.shape[0], -1])
    y_train = data['y_train'][:num_train]
                               
    X_val = data['X_val']
    X_val = np.reshape(X_val, [X_val.shape[0], -1])
    y_val = data['y_val']
    
    num_epochs = 10
    batch_sizes = [5,10,50]
    

    batch_size = batch_sizes[0]
    print('No normalization: batch size = ', 5)    
    baseline = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10,
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=False)

    # use an aggresive learning rate
    baseline_trace = baseline.train(X_train, y_train, X_val, y_val,
                                    learning_rate=10**-3,
                                    reg=np.float32(1e-5), 
                                    num_iters=num_train * num_epochs // batch_size ,
                                    batch_size=batch_size, 
                                    verbose=True) # train the model with batch normalization

    
    
    

    bn_traces = []
    for i in range(len(batch_sizes)):
        
        batch_size = batch_sizes[i]
        print('Normalization: batch size = ',batch_size)

    
        bn_model = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10, 
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=True)

        # use an aggresive learning rate
        bn_net_trace = bn_model.train(X_train, y_train, X_val, y_val,
                          learning_rate=10**-3,
                          reg=np.float32(1e-5), 
                          num_iters=num_train * num_epochs // batch_size ,
                          batch_size=batch_size, 
                          verbose=True) # train the model with batch normalization

    
        bn_traces.append(bn_net_trace)
        
    return bn_traces, baseline_trace, batch_sizes

batch_sizes = [5,10,50]
bn_traces, baseline_trace, batch_sizes = run_batchsize_experiments()
# Out:
# No normalization: batch size =  5
# iteration 0 / 2000: objective 11.514304
# iteration 100 / 2000: objective 11.530845
# iteration 200 / 2000: objective 11.489233
# iteration 300 / 2000: objective 11.541492
# iteration 400 / 2000: objective 11.467241
# iteration 500 / 2000: objective 11.549950
# iteration 600 / 2000: objective 11.446713
# iteration 700 / 2000: objective 11.555370
# iteration 800 / 2000: objective 11.426662
# iteration 900 / 2000: objective 11.555120
# iteration 1000 / 2000: objective 11.404947
# iteration 1100 / 2000: objective 11.544064
# iteration 1200 / 2000: objective 11.375858
# iteration 1300 / 2000: objective 11.504647
# iteration 1400 / 2000: objective 11.316720
# iteration 1500 / 2000: objective 11.314794
# iteration 1600 / 2000: objective 11.028091
# iteration 1700 / 2000: objective 9.682540
# iteration 1800 / 2000: objective 10.528839
# iteration 1900 / 2000: objective 9.623591
# Normalization: batch size =  5
# iteration 0 / 2000: objective 11.153889
# iteration 100 / 2000: objective 11.052471
# iteration 200 / 2000: objective 10.618526
# iteration 300 / 2000: objective 10.553571
# iteration 400 / 2000: objective 9.681596
# iteration 500 / 2000: objective 10.391817
# iteration 600 / 2000: objective 9.728931
# iteration 700 / 2000: objective 10.065411
# iteration 800 / 2000: objective 9.716859
# iteration 900 / 2000: objective 9.567931
# iteration 1000 / 2000: objective 9.858311
# iteration 1100 / 2000: objective 9.987319
# iteration 1200 / 2000: objective 9.086870
# iteration 1300 / 2000: objective 8.940807
# iteration 1400 / 2000: objective 8.385169
# iteration 1500 / 2000: objective 10.312508
# iteration 1600 / 2000: objective 8.504206
# iteration 1700 / 2000: objective 10.184566
# iteration 1800 / 2000: objective 7.776400
# iteration 1900 / 2000: objective 10.086930
# Normalization: batch size =  10
# iteration 0 / 1000: objective 22.829689
# iteration 100 / 1000: objective 22.076612
# iteration 200 / 1000: objective 19.644665
# iteration 300 / 1000: objective 18.230341
# iteration 400 / 1000: objective 16.716566
# iteration 500 / 1000: objective 14.340439
# iteration 600 / 1000: objective 15.383872
# iteration 700 / 1000: objective 13.615892
# iteration 800 / 1000: objective 15.728397
# iteration 900 / 1000: objective 13.568263
# Normalization: batch size =  50
# iteration 0 / 200: objective 115.275673
# iteration 100 / 200: objective 80.218964

# %%
plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Batch Normalization)','Epoch', 
                      baseline_trace['train_acc_history'], 
                      [trace['train_acc_history'] for trace in bn_traces],
                      bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Batch Normalization)','Epoch', 
                      baseline_trace['val_acc_history'], 
                      [trace['val_acc_history'] for trace in bn_traces],
                      bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# ## Inline Question 2:
# Describe the results of this experiment. What does this imply about the relationship between batch normalization and batch size? Why is this relationship observed?
#
# ## Answer:
# I definitely saw a recent paper talking about how batch norm does not perform well on mini batches (https://arxiv.org/pdf/1702.03275.pdf) but, these results seem to say quite the opposite. They imply that batch normalization performs better at smaller batches 5-10, as opposed to larger batches around 50, so at least for these samples batch normalization performance roughly increases as batch size decreases.
#
# Minibatching allows more iterations in the same amount of time, taking a lot of little steps in more approximate directions. I think the relationship is observed because batch normalization makes correct direction easier to find, so the approximate directions are more accurate.
